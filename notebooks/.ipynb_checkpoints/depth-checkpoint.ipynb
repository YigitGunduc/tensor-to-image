depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_133800_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134620_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134634_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134644_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134657_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134710_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134725_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134746_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134754_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_134806_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_141826_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_142313_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_142329_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_142717_depth_vi.png',
#  '../../../depth/dataset/test/LR/12. Livingroom/depth_vi/in_03_160308_142739_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_00_160215_184307_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_00_160215_185018_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_00_160215_192756_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_00_160215_193549_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_00_160217_122304_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_00_160217_122645_depth_vi.png',
#  '../../../depth/dataset/test/LR/13. Kitchen/depth_vi/in_03_160308_122248_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_112009_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_112256_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_114028_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_115031_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_115519_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_121319_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_124239_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_125030_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_125904_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_130840_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_130953_depth_vi.png',
#  '../../../depth/dataset/test/LR/15. Restaurant/depth_vi/in_00_160225_141253_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_171128_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_171130_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_171705_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_171707_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_172559_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_172619_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_172717_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_172735_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_172755_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_173106_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_173130_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_173250_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_173314_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_173445_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_173720_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_174312_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_174527_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_181804_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_182425_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160202_182554_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_01_160205_151211_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_03_160216_174605_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_03_160216_175207_depth_vi.png',
#  '../../../depth/dataset/test/LR/18. Store/depth_vi/in_03_160216_180146_depth_vi.png']

# %%
BUFFER_SIZE = 400
EPOCHS = 100
LAMBDA = 100
BATCH_SIZE = 8
IMG_WIDTH = 256
IMG_HEIGHT = 256
patch_size = 8
num_patches = (IMG_HEIGHT // patch_size) ** 2
projection_dim = 64
embed_dim = 64
num_heads = 2 
ff_dim = 32

# %%
real = []
targets = []

# %%
def load(path):

    image_path = path[:-12] + 'c.png'
    image_path = image_path.replace("depth_vi", "color")
    depth_path = path[:-12] + 'depth_vi.png'


    input_image = tf.io.read_file(image_path)
    input_image = tf.image.decode_jpeg(input_image)
    
    target_image = tf.io.read_file(depth_path)
    target_image = tf.image.decode_jpeg(target_image)
    
    input_image = tf.cast(input_image, tf.float32)
    target_image = tf.cast(target_image, tf.float32)


    return input_image, target_image

# %%
def resize(input_image, real_image, height, width):
    input_image = tf.image.resize(input_image, [height, width],
                                method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)
    real_image = tf.image.resize(real_image, [height, width],
                               method=tf.image.ResizeMethod.NEAREST_NEIGHBOR)

    return input_image, real_image

# %%
def normalize(input_image, target_image):
    input_image = input_image / 255
    target_image = target_image / 255

    return input_image, target_image

# %%
def load_image_train(depth_path):
    input_image, target = load(depth_path)
    input_image, target = resize(input_image, target,
                                   IMG_HEIGHT, IMG_WIDTH)
    input_image, target = normalize(input_image, target)

    return input_image, target

# %%
real = []
targets = []
import numpy as np
for i in range(len(target_paths)):
    #inputs, target = load(target_paths[i])
    inputs, target = load_image_train(target_paths[i])
    #inputs, target =  normalize(inputs, target)
    real.append(inputs)
    targets.append(target)

real = np.array(real)
targets = np.array(targets)

# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
plt.imshow(real[23])
print(real[12].shape)
# Out:
# (256, 256, 3)

# %%
plt.imshow(targets[23].reshape(256, 256))
print(targets[1].shape)
# Out:
# (256, 256, 1)

# %%
import tensorflow as tf

import os
import time

from matplotlib import pyplot as plt
from IPython import display

# %%
def downsample(filters, size, apply_batchnorm=True):
    initializer = tf.random_normal_initializer(0., 0.02)

    result = tf.keras.Sequential()
    result.add(
      tf.keras.layers.Conv2D(filters, size, strides=2, padding='same',
                             kernel_initializer=initializer, use_bias=False))

    if apply_batchnorm:
        result.add(tf.keras.layers.BatchNormalization())

    result.add(tf.keras.layers.LeakyReLU())

    return result

# %%
class Patches(tf.keras.layers.Layer):
    def __init__(self, patch_size):
        super(Patches, self).__init__()
        self.patch_size = patch_size

    def call(self, images):
        batch_size = tf.shape(images)[0]
        patches = tf.image.extract_patches(
            images=images,
            sizes=[1, self.patch_size, self.patch_size, 1],
            strides=[1, self.patch_size, self.patch_size, 1],
            rates=[1, 1, 1, 1],
            padding="SAME",
        )
        patch_dims = patches.shape[-1]
        patches = tf.reshape(patches, [batch_size, -1, patch_dims])
        return patches

# %%
class PatchEncoder(tf.keras.layers.Layer):
    def __init__(self, num_patches, projection_dim):
        super(PatchEncoder, self).__init__()
        self.num_patches = num_patches
        self.projection = layers.Dense(units=projection_dim)
        self.position_embedding = layers.Embedding(
            input_dim=num_patches, output_dim=projection_dim
        )

    def call(self, patch):
        positions = tf.range(start=0, limit=self.num_patches, delta=1)
        encoded = self.projection(patch) + self.position_embedding(positions)
        return encoded

# %%
class TransformerBlock(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, ff_dim, rate=0.1):
        super(TransformerBlock, self).__init__()
        self.att = layers.MultiHeadAttention(num_heads=num_heads, key_dim=embed_dim)
        self.ffn = tf.keras.Sequential(
            [layers.Dense(ff_dim, activation="relu"), layers.Dense(embed_dim),]
        )
        self.layernorm1 = layers.LayerNormalization(epsilon=1e-6)
        self.layernorm2 = layers.LayerNormalization(epsilon=1e-6)
        self.dropout1 = layers.Dropout(rate)
        self.dropout2 = layers.Dropout(rate)

    def call(self, inputs, training):
        attn_output = self.att(inputs, inputs)
        attn_output = self.dropout1(attn_output, training=training)
        out1 = self.layernorm1(inputs + attn_output)
        ffn_output = self.ffn(out1)
        ffn_output = self.dropout2(ffn_output, training=training)
        return self.layernorm2(out1 + ffn_output)

# %%
from tensorflow import Tensor
from tensorflow.keras.layers import Input, Conv2D, ReLU, BatchNormalization,\
                                    Add, AveragePooling2D, Flatten, Dense
from tensorflow.keras.models import Model

def relu_bn(inputs: Tensor) -> Tensor:
    relu = ReLU()(inputs)
    bn = BatchNormalization()(relu)
    return bn

def residual_block(x: Tensor, downsample: bool, filters: int, kernel_size: int = 3) -> Tensor:
    y = Conv2D(kernel_size=kernel_size,
               strides= (1 if not downsample else 2),
               filters=filters,
               padding="same")(x)
    y = relu_bn(y)
    y = Conv2D(kernel_size=kernel_size,
               strides=1,
               filters=filters,
               padding="same")(y)

    if downsample:
        x = Conv2D(kernel_size=1,
                   strides=2,
                   filters=filters,
                   padding="same")(x)
    out = Add()([x, y])
    out = relu_bn(out)
    return out

# %%
from tensorflow.keras import layers

def Generator():

    inputs = layers.Input(shape=(256, 256, 3))

    patches = Patches(patch_size)(inputs)
    encoded_patches = PatchEncoder(num_patches, projection_dim)(patches)

    x = TransformerBlock(64, num_heads, ff_dim)(encoded_patches)
    x = TransformerBlock(64, num_heads, ff_dim)(x)
    x = TransformerBlock(64, num_heads, ff_dim)(x)
    x = TransformerBlock(64, num_heads, ff_dim)(x)

    x = layers.Reshape((8, 8, 1024))(x)

    x = layers.Conv2DTranspose(512, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = residual_block(x, downsample=False, filters=512)

    x = layers.Conv2DTranspose(256, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = residual_block(x, downsample=False, filters=256)

    x = layers.Conv2DTranspose(64, (5, 5), strides=(2, 2), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)
    
    x = residual_block(x, downsample=False, filters=64)

    x = layers.Conv2DTranspose(32, (5, 5), strides=(4, 4), padding='same', use_bias=False)(x)
    x = layers.BatchNormalization()(x)
    x = layers.LeakyReLU()(x)

    x = residual_block(x, downsample=False, filters=32)

    x = layers.Conv2D(1, (3, 3), strides=(1, 1), padding='same', use_bias=False, activation='tanh')(x)

    return tf.keras.Model(inputs=inputs, outputs=x)

# %%
generator = Generator()
tf.keras.utils.plot_model(generator, show_shapes=True, dpi=64)
# Out:
# ('Failed to import pydot. You must `pip install pydot` and install graphviz (https://graphviz.gitlab.io/download/), ', 'for `pydotprint` to work.')

# %%
generator.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# patches (Patches)               (None, None, 192)    0           input_1[0][0]
# __________________________________________________________________________________________________
# patch_encoder (PatchEncoder)    (None, 1024, 64)     77888       patches[0][0]
# __________________________________________________________________________________________________
# transformer_block (TransformerB (None, 1024, 64)     37664       patch_encoder[0][0]
# __________________________________________________________________________________________________
# transformer_block_1 (Transforme (None, 1024, 64)     37664       transformer_block[0][0]
# __________________________________________________________________________________________________
# transformer_block_2 (Transforme (None, 1024, 64)     37664       transformer_block_1[0][0]
# __________________________________________________________________________________________________
# transformer_block_3 (Transforme (None, 1024, 64)     37664       transformer_block_2[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 8, 8, 1024)   0           transformer_block_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 16, 16, 512)  13107200    reshape[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 16, 16, 512)  2048        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 16, 16, 512)  0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 16, 16, 512)  2359808     leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# re_lu (ReLU)                    (None, 16, 16, 512)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 16, 16, 512)  2048        re_lu[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 16, 16, 512)  2359808     batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 16, 16, 512)  0           leaky_re_lu[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# re_lu_1 (ReLU)                  (None, 16, 16, 512)  0           add[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 16, 16, 512)  2048        re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 32, 32, 256)  3276800     batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 256)  1024        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 256)  590080      leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# re_lu_2 (ReLU)                  (None, 32, 32, 256)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 256)  1024        re_lu_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 256)  590080      batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           leaky_re_lu_1[0][0]
#                                                                  conv2d_3[0][0]
# __________________________________________________________________________________________________
# re_lu_3 (ReLU)                  (None, 32, 32, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 256)  1024        re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 64, 64, 64)   409600      batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 64)   256         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 64, 64, 64)   0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 64)   36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# re_lu_4 (ReLU)                  (None, 64, 64, 64)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 64, 64, 64)   256         re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   36928       batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 64)   0           leaky_re_lu_2[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# re_lu_5 (ReLU)                  (None, 64, 64, 64)   0           add_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 64)   256         re_lu_5[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 32) 51200       batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 256, 256, 32) 128         conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 256, 256, 32) 0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 256, 256, 32) 9248        leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# re_lu_6 (ReLU)                  (None, 256, 256, 32) 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 256, 256, 32) 128         re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 256, 256, 32) 9248        batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256, 256, 32) 0           leaky_re_lu_3[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# re_lu_7 (ReLU)                  (None, 256, 256, 32) 0           add_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 256, 256, 32) 128         re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 1)  288         batch_normalization_11[0][0]
# ==================================================================================================
# Total params: 23,076,128
# Trainable params: 23,070,944
# Non-trainable params: 5,184
# __________________________________________________________________________________________________

# %%
tf.config.run_functions_eagerly(False)

# %%
loss_object = tf.keras.losses.BinaryCrossentropy(from_logits=True)

# %%
def generator_loss(disc_generated_output, gen_output, target):
    gan_loss = loss_object(tf.ones_like(disc_generated_output), disc_generated_output)

    # mean absolute error
    l1_loss = tf.reduce_mean(tf.abs(target - gen_output))

    total_gen_loss = gan_loss + (LAMBDA * l1_loss)

    return total_gen_loss, gan_loss, l1_loss

# %%
tf.config.run_functions_eagerly(True)

# %%
generator_optimizer = tf.keras.optimizers.Adam(2e-4, beta_1=0.5)

# %%
def generate_images(model, test_input, tar):
    prediction = model(test_input, training=True)
    plt.figure(figsize=(15, 15))

    display_list = [test_input[0], np.array(tar[0]).reshape(256, 256), np.array(prediction[0]).reshape(256, 256)]
    title = ['Input Image', 'Ground Truth', 'Predicted Image']

    for i in range(3):
        plt.subplot(1, 3, i+1)
        plt.title(title[i])
        # getting the pixel values between [0, 1] to plot it.
        plt.imshow(display_list[i] * 0.5 + 0.5)
        plt.axis('off')
    plt.show()

def generate_batch_images(model, test_input, tar):
    for i in range(len(test_input)):
        prediction = model(test_input, training=True)
        plt.figure(figsize=(15, 15))

        display_list = [test_input[i], tar[i], prediction[i]]
        title = ['Input Image', 'Ground Truth', 'Predicted Image']

        for i in range(3):
            plt.subplot(1, 3, i+1)
            plt.title(title[i])
            # getting the pixel values between [0, 1] to plot it.
            plt.imshow(display_list[i] * 0.5 + 0.5)
            plt.axis('off')
        plt.show()

# %%
@tf.function
def train_step(input_image, target):
    with tf.device('/device:GPU:0'):
        with tf.GradientTape() as gen_tape, tf.GradientTape() as disc_tape:
            gen_output = generator(input_image, training=True)
            gen_total_loss = tf.reduce_mean(tf.abs(target - gen_output))
        

        generator_gradients = gen_tape.gradient(gen_total_loss,
                                              generator.trainable_variables)
        generator_optimizer.apply_gradients(zip(generator_gradients,
                                              generator.trainable_variables))

# %%
def fit(train_ds, epochs, test_ds):
    for epoch in range(epochs):
        start = time.time()

        display.clear_output(wait=True)

        print("Epoch: ", epoch)

        # Train
        for n, (input_image, target) in train_ds.enumerate():
            print('.', end='')
            if (n+1) % 100 == 0:
                print()
            train_step(input_image, target)
        print()

        generator.save_weights(f'depth-gen-weights.h5')

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((real, targets))

train_dataset = train_dataset.batch(BATCH_SIZE)

# %%
fit(train_dataset, 10000, train_dataset)
# Out:
# Epoch:  296
# .................................................

# %%
generator.save_weights('gen-depth-weights.h5')
discriminator.save_weights('dics-depth-weights.h5')

# %%
for example_input, example_target in train_dataset.take(54):
    generate_images(generator, example_input, example_target)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-65c93fbe02c8> in <module>
#       1 for example_input, example_target in train_dataset.take(54):
# ----> 2     generate_images(generator, example_input, example_target)
#
# <ipython-input-62-8ef22da2c0de> in generate_images(model, test_input, tar)
#       1 def generate_images(model, test_input, tar):
# ----> 2     prediction = model(test_input, training=True)
#       3     plt.figure(figsize=(15, 15))
#       4
#       5     display_list = [test_input[0], np.array(tar[0]).reshape(256, 256), np.array(prediction[0]).reshape(256, 256)]
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in call(self, inputs, training, mask)
#     422         a list of tensors if there are more than one outputs.
#     423     """
# --> 424     return self._run_internal_graph(
#     425         inputs, training=training, mask=mask)
#     426
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/functional.py in _run_internal_graph(self, inputs, training, mask)
#     558
#     559         args, kwargs = node.map_arguments(tensor_dict)
# --> 560         outputs = node.layer(*args, **kwargs)
#     561
#     562         # Update tensor_dict.
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# <ipython-input-51-97c481ccb11b> in call(self, inputs, training)
#      12
#      13     def call(self, inputs, training):
# ---> 14         attn_output = self.att(inputs, inputs)
#      15         attn_output = self.dropout1(attn_output, training=training)
#      16         out1 = self.layernorm1(inputs + attn_output)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1010         with autocast_variable.enable_auto_cast_variables(
#    1011             self._compute_dtype_object):
# -> 1012           outputs = call_fn(inputs, *args, **kwargs)
#    1013
#    1014         if self._activity_regularizer:
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/multi_head_attention.py in call(self, query, value, key, attention_mask, return_attention_scores, training)
#     471     value = self._value_dense(value)
#     472
# --> 473     attention_output, attention_scores = self._compute_attention(
#     474         query, key, value, attention_mask, training)
#     475     attention_output = self._output_dense(attention_output)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/multi_head_attention.py in _compute_attention(self, query, key, value, attention_mask, training)
#     433     # Take the dot product between "query" and "key" to get the raw
#     434     # attention scores.
# --> 435     attention_scores = special_math_ops.einsum(self._dot_product_equation, key,
#     436                                                query)
#     437
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/special_math_ops.py in einsum(equation, *inputs, **kwargs)
#     749       - number of inputs or their shapes are inconsistent with `equation`.
#     750   """
# --> 751   return _einsum_v2(equation, *inputs, **kwargs)
#     752
#     753
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/special_math_ops.py in _einsum_v2(equation, *inputs, **kwargs)
#    1178       if ellipsis_label:
#    1179         resolved_equation = resolved_equation.replace(ellipsis_label, '...')
# -> 1180       return gen_linalg_ops.einsum(inputs, resolved_equation)
#    1181
#    1182     # Send fully specified shapes to opt_einsum, since it cannot handle unknown
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/ops/gen_linalg_ops.py in einsum(inputs, equation, name)
#    1070   if tld.is_eager:
#    1071     try:
# -> 1072       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    1073         _ctx, "Einsum", name, inputs, "equation", equation)
#    1074       return _result
#
# KeyboardInterrupt:
